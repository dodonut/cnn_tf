# %%
import preprocessing
import pandas as pd
import numpy as np
import helper
import store
import constants
import metrics
from sklearn.decomposition import PCA
import os
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

Join = os.path.join
import importlib
importlib.reload(preprocessing)
importlib.reload(metrics)
# Out:
# <module 'metrics' from 'd:\\TCC\\Code\\cnn_tf\\tcc\\metrics.py'>

# %%
trainpath = Join(constants.PREPROCESS_STORE, 'Train')
testpath = Join(constants.PREPROCESS_STORE, 'Test')
# for i in range(16):
cube1 = helper.get_cube_by_index(trainpath, 0, 'calib.pickle')
oldmat1 = helper.get_cube_by_index(trainpath, 0, 'mat_nobg.pickle')

cube2 = helper.get_cube_by_index(trainpath, 1, 'calib.pickle')
oldmat2 = helper.get_cube_by_index(trainpath, 1, 'mat_nobg.pickle')

# %%
ncube1 = preprocessing.preprocess_training_data_from_calibration_with_filters(cube1)
ncube2 = preprocessing.preprocess_training_data_from_calibration_with_filters(cube2)
# Out:
# aqui
# C:\Users\Vinicius Moraes\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# C:\Users\Vinicius Moraes\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:255: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   "Numerical issues were encountered "
# aqui
# C:\Users\Vinicius Moraes\AppData\Roaming\Python\Python37\site-packages\sklearn\preprocessing\_data.py:236: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   "Numerical issues were encountered "
# ...

# %%
cc1 = helper.remove_pixels_from_all_dir(ncube1, 30, 60, 50, 30)
helper.show_img_on_wave(cc1, 0)

# %%
cc2 = helper.remove_pixels_from_all_dir(ncube2, 20, 0,0,0)
helper.show_img_on_wave(cc2, 0)

# %%
nm_nof1 = helper.remove_blank_lines(helper.hsi2matrix(cc1))
nm_nof2 = helper.remove_blank_lines(helper.hsi2matrix(cc2))

nm_nof1 = nm_nof1 - np.mean(nm_nof1)
nm_nof2 = nm_nof2 - np.mean(nm_nof2)

# %%
name1 = constants.LABELS[0]
name2 = constants.LABELS[1]
metrics.plot_dif_spectrum_refs([nm_nof1, oldmat1, nm_nof2, oldmat2], ['aereus','aereus_filters','subtilis','subtilis_filters'], True, False, True, strict_labels=True)

# %%
store.
